# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import warnings

# %%
data = pd.read_csv("supermarket_sales.csv")

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ## DISPLAY TOP 5 ROWS FROM THE DATASET

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# ## 2.DISPLAY LAST 5 ROWS FROM THE DATASET

# %%
data.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
#Invoice id: Computer generated sales slip invoice identification number

# Branch: Branch of supercenter

#(3 branches are available identified A,B and C).

#City: Location of supercenters

#Customer type: Type of customers,recorded 
#by members for customers using member card
#add Normal for without member card.

#Gender: Gender type of customer

#Product line: General item categorization groups
# -Electronic accessories , Fashion Accessories,
#Food and beverages, Health and beauty, Home
#and lifestyle, Sports and travel

#Unit price: Price of each product in $

#Quantity: Number of products purchased by customer

#Tax: 5% tax fee for customer buying

#Total: Total price including tax

#Date: Date of purchase ( Record available from January 2019 to March 2019)

#Time:Purchase time(10am to 9pm)

#Payment: Payment mode used by customer for purchase
#(3 methods are availabke- Cash, Credit Card and Ewallet)

#COGS: Cost of Goods Sold

#Gross margin percentage: Gross margin percentage

#Gross income: Gross income

#Rating: Customer stratification rating on their
#overall shopping experience ( On a scale of 1 to 10)

# %% [markdown]
# ## 3.PRINT RANDOM 5 ROWS FROM OUR DATASET

# %%
data.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 452  727-17-0390      A     Yangon        Normal  Female   Food and beverages
# 952  574-80-1489      B   Mandalay        Member  Female   Food and beverages
# 416  750-57-9686      C  Naypyitaw        Normal  Female   Home and lifestyle
# 597  123-35-4896      C  Naypyitaw        Normal  Female    Sports and travel
# 116  291-32-1427      B   Mandalay        Member    Male  Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 452       63.61         5  15.9025  333.9525  3/16/2019  12:43      Ewallet
# 952       62.85         4  12.5700  263.9700  2/25/2019  13:22      Ewallet
# 416       45.38         4   9.0760  190.5960   1/8/2019  13:48  Credit card
# 597       46.66         9  20.9970  440.9370  2/17/2019  19:11      Ewallet
# 116       21.94         5   5.4850  115.1850   3/5/2019  12:29      Ewallet
#
# ...

# %% [markdown]
# ## 4.FIND SHAPE OF OUR DATASET( Number of rows and columns)

# %%
data.shape
# Out:
# (1000, 17)

# %%
print("Number of columns",data.shape[0])
print("Number of rows",data.shape[1])
# Out:
# Number of columns 1000
# Number of rows 17

# %% [markdown]
# ## 5.CHECK FOR NULL VALUES IN THE DATASET

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# ## 6.Get Information about the Dataset like Total Number Rows,Total NUmber of Columns,Data Types of each column and memory requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# ## 7.Get Overall Statistics about the Dataset

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
num=[]
cat=[]
for column in data.columns:
    if data[column].nunique() >10:
        num.append(column)
    else:
        cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# ## 1.Find Aggregate Sales among Branches ( Categorical column)

# %%
sns.countplot(data,x='Branch',color= "purple")  #Using seaborn library
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
data['Branch'].value_counts().plot(kind= "pie",autopct= " %1.2f%% ")     #Using pandas library
# Out:
# <Axes: ylabel='count'>

# %%
data['Branch'].value_counts().plot(kind= "bar")     #Using pandas library
# Out:
# <Axes: xlabel='Branch'>

# %% [markdown]
# ## 2.Find the Most Popular Payment Method used by Customers(Categorical Column)

# %%
data['Payment'].value_counts().plot(kind='bar',color=')
# Out:
# <Axes: xlabel='Payment'>

# %% [markdown]
# ## 2.Find the Distribution of Customer Ratings (Numerical Column)

# %%
sns.distplot(data['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
data['Rating'].skew()
# Out:
# 0.00900964876573073

# %% [markdown]
# ## 4.Find the Distribution of Cost of Goods Sold (Numerical Column)

# %%
sns.distplot(data['cogs'])
# Out:
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
data['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
sns.boxplot(data['cogs'])
# Out:
# <Axes: ylabel='cogs'>

# %%
data['cogs'].median()   ##Q2 ( MIDDLE LINE represented in the BoxPlot)
# Out:
# 241.76

# %% [markdown]
# # BIVARIATE ANALYSIS/MULTIVARIATE ANALYSIS

# %% [markdown]
# ## 1. Does the Cost of Goods Affect the Ratings that the Customers Provide? (Numerical-Numerical)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.scatterplot(data,x='cogs',y='Rating')
# Out:
# <Axes: xlabel='cogs', ylabel='Rating'>

# %% [markdown]
# ## 2.Does Gross Income Affect the Ratings that Customers provide? (Numerical-Numerical)

# %%
sns.scatterplot(data,x = 'gross income',y = 'Rating')
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %% [markdown]
# ## 3. Find the Most Profitable Branch as per Gross Income (Numerical-Categorical)

# %%
sns.barplot(data,x='Branch',y='gross income')     #bivariate
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.violinplot(x='Branch', y='gross income', data=data)         #bivariate
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(data,x ='Branch',y = 'gross income',hue=data['City'])     #multivariate analysis
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %% [markdown]
# ## 4.Finding Gender Wise Gross Income Distribution

# %%
data.groupby('Gender')['gross income'].plot(kind='hist', alpha=0.5, legend=True, figsize=(8,4))   #Using pandas(bivariate)
# Out:
# Gender
# Female    Axes(0.125,0.11;0.775x0.77)
# Male      Axes(0.125,0.11;0.775x0.77)
# Name: gross income, dtype: object

# %%
ax = sns.boxplot(data,x='Gender',y = 'gross income',palette="Set2")
ax.set_title("Gross Income VS Gender")   #bivariate
# Out:
# Text(0.5, 1.0, 'Gross Income VS Gender')

# %%
ay = sns.boxplot(data,x='Gender',y = 'gross income',palette="Set2",hue='Customer type')
ay.set_title("Gross Income VS Gender VS Customer Type")          #multivariate
# Out:
# Text(0.5, 1.0, 'Gross Income VS Gender VS Customer Type')

# %% [markdown]
# ## 5. Find the Product Line that Generates the Most Income ( Categorical-Numerical)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
ax=sns.barplot(x='Product line',y='gross income',data=data,palette='pastel')
ax.set_xticklabels(data['Product line'], rotation = 80)     #rotate labels by 80 degree
# Out:
# [Text(0, 0, 'Health and beauty'),
#  Text(1, 0, 'Electronic accessories'),
#  Text(2, 0, 'Home and lifestyle'),
#  Text(3, 0, 'Health and beauty'),
#  Text(4, 0, 'Sports and travel'),
#  Text(5, 0, 'Electronic accessories')]

# %% [markdown]
# ## 6.Find the Highest Unit Price in the Product Line (Numerical-Categorical)

# %%
ax=sns.barplot(x='Product line',y='Unit price',data=data,palette='bright')
ax.set_xticklabels(data['Product line'], rotation = 80)     #rotate labels by 60 degree
# Out:
# [Text(0, 0, 'Health and beauty'),
#  Text(1, 0, 'Electronic accessories'),
#  Text(2, 0, 'Home and lifestyle'),
#  Text(3, 0, 'Health and beauty'),
#  Text(4, 0, 'Sports and travel'),
#  Text(5, 0, 'Electronic accessories')]

# %% [markdown]
# ## 7. Find Different Payment Methods used by Customers Citywise ( Categorical-Categorical)

# %%
sns.heatmap(pd.crosstab(data['City'],data['Payment']))
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %% [markdown]
# ## 8.Which Product Line is Purchased in the Highest Quantity

# %%
(data.groupby("Product line").sum()['Quantity']).plot(kind='bar')
# Out:
# <Axes: xlabel='Product line'>

# %% [markdown]
# ## 9.Display Daily Sales by Day of the Week

# %%
dw_mapping={
    0:'Mon',
    1:'Tues',
    2:'Wed',
    3:'Thurs',
    4:'Fri',
    5:'Sat',
    6:'Sun'
}

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['day_of_week'] = data['Date'].dt.dayofweek.map(dw_mapping)
data.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender       Product line  \
# 0  750-67-8428      A  Yangon        Member  Female  Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time  Payment    cogs  \
# 0       74.69         7  26.1415  548.9715 2019-01-05  13:08  Ewallet  522.83
#
#    gross margin percentage  gross income  Rating day_of_week
# 0                 4.761905       26.1415     9.1         Sat

# %%
data['day_of_week'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='day_of_week'>

# %% [markdown]
# ## 10. Which will be the Highest Months for Sales

# %%
month_mapping={
    0:'January',
    1:'February',
    2:'March',
    3:'April',
    4:'May',
    5:'June',
    6:'July',
    7:'August',
    8:'September',
    9:'October',
    10:'November',
    11:'December'
                }

# %%
data['Month']=data['Date'].dt.month.map(month_mapping)

# %%
data.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender       Product line  \
# 0  750-67-8428      A  Yangon        Member  Female  Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time  Payment    cogs  \
# 0       74.69         7  26.1415  548.9715 2019-01-05  13:08  Ewallet  522.83
#
#    gross margin percentage  gross income  Rating day_of_week     Month
# 0                 4.761905       26.1415     9.1         Sat  February

# %%
data['Month'].value_counts().plot(kind='bar',stacked=True,color='red')
# Out:
# <Axes: xlabel='Month'>
